# %%
# %%file FlubClub.py
import numpy as np
from StringIO import StringIO
import matplotlib.pyplot as plt
import requests
import glob, os
from PIL import Image, ImageOps

class Blob():
    def __init__(self):
        """
        Construct an empty flubber array for the purpose of filling 
        it with information determined by other functions.
        """
        self.loc = [] # Stores the number of pixels; AKA mass or size of flubber.
        self._mass = 0
        
    def __repr__(self):
        return "<loc:%s mass:%s>" % (self.loc, self._mass)
    
    def __str__(self):
        return "From str method of Blob: loc is %s, \n mass is %s \n com is: %s" % (self.loc, self._mass, self.centerOfMass)
        
    def add(self, (i, j)):
        """
        Add a pixel (i, j) to the flubber as part of the drawing process.
        """
        self.loc.append((i, j));
        self._mass = (len(self.loc))
        
    def mass(self):
        """
        Return number of pixels added equal to its mass.
        """
        self._mass = (len(self.loc))
        return self._mass
    
    def distanceTo(self, duece):
        """
        Return distance between the center of mass of this flubber and another.
        """
        self.dist = round(((self.centerOfMass()[0] - duece.centerOfMass()[0])**2 + \
                     (self.centerOfMass()[1] - duece.centerOfMass()[1])**2)**.5, 4)
        return self.dist
        
    def centerOfMass(self):
        """
        Return tuple of (x,y) values for this flubber's center of mass.
        Format center-of-mass coordinates with 4 sig figs.
        """
        x = 0; y = 0;
        for point in self.loc:
            x += point[0]
            y += point[1]
        return (x / len(self.loc), y / len(self.loc))

        
def flubberFinder(P, picture, tau):
    '''find all flubbers in the picture using the luminance threshold tau.'''
    BLACK = (0, 0, 0); WHITE = (255, 255, 255); RED = (255, 0, 0);  float(tau);
    FlubArray = [] 
    
    tempImage = picture.load()
    horLen, verLen = picture.size
    monochrome(picture, tau)    
    
    for x in range(horLen):
        for y in range(verLen):
            if tempImage[x, y] == BLACK:
                FlubArray.append(fill(picture, horLen, verLen, x, y))
    
    return FlubArray

def monochrome(picture, tau):
    '''Reads and loads a temporary image to convert to black or white in regards to luminance threshold tau. '''
    BLACK = (0, 0, 0); WHITE = (255, 255, 255); tempImage = picture.load(); horLen, verLen = picture.size;
        
    for x in range(horLen):
        for y in range(verLen):
            r,g,b = tempImage[x, y]
            if r+g+b >= tau:
                tempImage[x,y] = BLACK
            else:
                tempImage[x,y] = WHITE

def fill(picture, horLen, verLen, xi, yi):  #Using Fastfill algorithm.
    '''Lists all the pixels that are associated with currentFlubber that haven't been filled or looked at.'''
    BLACK = (0, 0, 0); 
    RED = (255, 0, 0); 
    img = picture.load();
    queue = [(xi, yi)];
    if img[xi, yi] == BLACK: #If pixel is black--track covered by changing to red.
        img[xi, yi] = RED
        Flubber = Blob();
        while queue:
            x, y, queue = queue[0][0], queue[0][1], queue[1:]
            # Horizontal/Vertical Postive/Negative Displacement
            Flubber.add((x, y)) # Add this pixel to the current flubber array.
            if x > 0 and (img[x - 1, y] == BLACK): # "and" is from FastFill algorithm.
                img[x - 1, y] = RED
                queue.append((x - 1, y))
            if x < (horLen - 1) and (img[x + 1, y] == BLACK):
                img[x + 1, y] = RED
                queue.append((x + 1, y))
            if y > 0 and (img[x, y - 1] == BLACK):
                img[x, y - 1] = RED
                queue.append((x, y - 1))
            if y < (verLen - 1) and (img[x, y + 1] == BLACK):
                img[x, y + 1] = RED
                queue.append((x, y + 1))
    #print str(Flubber)
    return Flubber
    
# Determines mass of all flubber by >= p pixels
def qualityFlubbers(P, listFlubbers): #getBeads(P) Function
    '''
    return all unit flubbers with >= P pixels. 
    '''
    tempListFlubbers = [] 
    #print dir(listFlubbers), str(listFlubbers.loc), str(listFlubbers._mass)
    for i in listFlubbers:
        if i._mass >= P:
            tempListFlubbers.append(i)
           #print i._mass
    return tempListFlubbers

def numFlubber(P, listFlubbers): #getBeads(P) Function (number of quality beads)
    '''
    return all unit flubbers with >= P pixels. 
    '''
    count = 0;
    for i in listFlubbers:
        if i._mass >= P:
            count += 1
    return count
# Out:
# Overwriting FlubClub.py

# %%
from IPython.html.widgets import interact, interactive
from matplotlib import *
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import glob, os
from FlubClub import *

# %%
def flubberTracking(P, tau, deltaP, frame1, frame2, isMilk):
    """
    Identifies beads (under specified value p and tau) in each image (using BlobFinder.)
    Writes to a file the radial displacement for each bead/frame (one per line, with '%10.4f'.)
    Note: beads tracked by deltaP requirements, and only by two consecutive frames.
    """
    print isMilk
    flubDispl = [];
    if isMilk == True:
        print "made it in"
        flub1 = Image.open(frame1)
        flub2 = Image.open(frame2)
        flubN = ImageOps.invert(flub1)
        flubM = ImageOps.invert(flub2)
    else:
        flubN = Image.open(frame1)
        flubM = Image.open(frame2)
        
    Flubs1 = qualityFlubbers(P, flubberFinder(P, flubN, tau))
    Flubs2 = qualityFlubbers(P, flubberFinder(P, flubM, tau))
    #print range(len(Flubs1)), range(len(Flubs2))
    for i in range(len(Flubs1)):
        minDelta = deltaP
        for j in range(len(Flubs2)):
            delta = Flubs1[i].distanceTo(Flubs2[j])
            if delta < minDelta:
                minDelta = delta
                nearestFlub = j
        if minDelta < deltaP:
            flubDispl.append(str(minDelta) + '\n')
            del Flubs2[nearestFlub]
    return flubDispl

def flubberFrameCompare(P, picture, tau, deltaP, data, isMilk):
    """
    Identifies beads (under specified value p and tau) in each image (using BlobFinder.)
    Writes to a file the radial displacement for each bead/frame (one per line, with '%10.4f'.)
    Note: beads tracked by deltaP requirements, and only by two consecutive frames.
    """
    flubDispl = []; write_data = open(data, 'w');
    for i in xrange(len(picture) - 1):
        flubDispl += flubberTracking(P, tau, deltaP, picture[i], picture[i+1], isMilk)
    write_data.writelines(flubDispl)
    write_data.close()

def constants(data):
    """Solve for Avogadro's constants'"""
    def selfDiffusion(data):
        dx = np.loadtxt(data)
        dx = dx * (0.1750 * (10.**(-6.)))
        D = (dx ** 2.).sum() / (2. * dx.size)
        return D
    def Boltzmann(data):
        T = 297.15; n = 9.135 * (10. **(-4.)); r = .5*10.**(-6.);
        return 6 * np.pi * n * r * selfDiffusion(data) / T
    def solveAvos(data):
        R = 8.31457; k = Boltzmann(data);
        return R / k
    D = selfDiffusion(data); B = Boltzmann(data); A = solveAvos(data);
    Na = 6.0221413e+23; NaDifference = round(((Na - A)/Na)*100., 4)
    print "Displacement:","{0:4e}".format(D), "m/pix"
    print "Boltzmann's:","{0:4e}".format(B), "J/K"
    print "Avogadro's:","{0:4e}".format(A), "molecules/mole"
    print "Perc Diff for Avos:","{0:4e}".format(NaDifference)

# %%
print "Run6"
constants('run6/frame00052.dat')
print "------------------------"
print "Milk data"
constants('milkLewis/Lewis_T0002.dat')
# Out:
# Run6
# Displacement: 4.288518e-13 m/pix
# Boltzmann's: 1.242542e-23 J/K
# Avogadro's: 6.691579e+23 molecules/mole
# Perc Diff for Avos: -1.111630e+01
# ------------------------
# Milk data
# Displacement: 2.879493e-13 m/pix
# Boltzmann's: 8.342955e-24 J/K
# Avogadro's: 9.965977e+23 molecules/mole
# Perc Diff for Avos: -6.548890e+01

# %%
def getFlubberMass(P, picture, tau):
    """
    Creates a BlobFinder object using a luminance threshold of tau.
    Prints out the mass and c.o.m of all beads with at least pixel size p.
    Prints out the mass and c.o.m of all the blobs. (beads w/ at least 1 pixel.)
    """
    img = picture.load(); count = 0
    Flubs = flubberFinder(P, picture, tau)
    print "Full list of Flubber masses (Any pixel size:)"
    for i in Flubs:
        print "Mass:", i._mass, "COM:", str(i.centerOfMass)
        count += 1
    print "Total Flubbers (Unsorted) count:", count
    print "-----------------------------------------------"
    print "-----------------------------------------------"
    print "Sorted Flubbers according to size P in pixels:"
    count = 0
    for flub in qualityFlubbers(P, Flubs):
        print "Mass:", flub._mass, "COM:", flub.centerOfMass
        count += 1
    print "Total Flubbers (>= P) count:", count

# %%
#### Writing data to files  RUN6 Data: 

def runAll():
    links = []; P = 25; tau = 320; deltaP = 20; isMilk = False
    for i in sorted(glob.glob('run6/*.jpg')):
        for j in sorted(glob.glob('run6/*.jpg')):
            links.append('run6/frame000' + j[13:15] + '.jpg')
            write_data = 'run6/frame000' + j[13:15] + '.dat'
            flubberFrameCompare(P, links, tau, deltaP, write_data, isMilk)


#### Extract data for Milk globules: 

def runAll2():
    P = 25; tau = 172; deltaP = 20; isMilk = True
    links = []
    for i in sorted(glob.glob('milkLewis/*.jpg')):
        for j in sorted(glob.glob('milkLewis/*.jpg')):
            links.append('milkLewis/Lewis_T' + j[17:21] + '.jpg')
            write_data = 'milkLewis/Lewis_T' + j[17:21] + '.dat'
            #print flubberFrameCompare(P, links, tau, deltaP, write_data, isMilk)
            flubberFrameCompare(P, links, tau, deltaP, write_data, isMilk)
            

runAll2()
# Out:
# True
# made it in
# True
# made it in
# True
# made it in
# True
# made it in
# True
# made it in
# True
# made it in
# True
# made it in
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6097c7a759f4> in <module>()
#      23
#      24
# ---> 25 runAll2()
#
# <ipython-input-10-6097c7a759f4> in runAll2()
#      20             write_data = 'milkLewis/Lewis_T' + j[17:21] + '.dat'
#      21             #print flubberFrameCompare(P, links, tau, deltaP, write_data, isMilk)
# ---> 22             flubberFrameCompare(P, links, tau, deltaP, write_data, isMilk)
#      23
#      24
#
# <ipython-input-6-25a9d93ca149> in flubberFrameCompare(P, picture, tau, deltaP, data, isMilk)
#      40     flubDispl = []; write_data = open(data, 'w');
#      41     for i in xrange(len(picture) - 1):
# ---> 42         flubDispl += flubberTracking(P, tau, deltaP, picture[i], picture[i+1], isMilk)
#      43     write_data.writelines(flubDispl)
#      44     write_data.close()
#
# <ipython-input-6-25a9d93ca149> in flubberTracking(P, tau, deltaP, frame1, frame2, isMilk)
#      18
#      19     Flubs1 = qualityFlubbers(P, flubberFinder(P, flubN, tau))
# ---> 20     Flubs2 = qualityFlubbers(P, flubberFinder(P, flubM, tau))
#      21     #print range(len(Flubs1)), range(len(Flubs2))
#      22     for i in range(len(Flubs1)):
#
# C:\Users\Hazrat Mahdie\PHYS202-S14\BrownianMotion\FlubClub.py in flubberFinder(P, picture, tau)
#      66     for x in range(horLen):
#      67         for y in range(verLen):
# ---> 68             if tempImage[x, y] == BLACK:
#      69                 FlubArray.append(fill(picture, horLen, verLen, x, y))
#      70
#
# KeyboardInterrupt:

# %%
#### Run6 Mass data
links = []; 
for i in sorted(glob.glob('run6/*.jpg')):
    for j in sorted(glob.glob('run6/*.jpg')):
        links.append('run6/frame' + j[10:15] + '.jpg')
img = Image.open(links[4]); img.load();
getFlubberMass(25, img, 500)

# %%
#### Milk Mass data

linksMilk = [];
for i in sorted(glob.glob('milkLewis/*.jpg')):
    for j in sorted(glob.glob('milkLewis/*.jpg')):
        linksMilk.append('milkLewis/Lewis_T' + j[17:21] + '.jpg')
img = Image.open(linksMilk[4]); tempImage = ImageOps.invert(img);
getFlubberMass(25, tempImage, 172)
# Out:
# Full list of Flubber masses (Any pixel size:)
# Mass: 315 COM: <bound method Blob.centerOfMass of <loc:[(1, 984), (2, 984), (1, 985), (3, 984), (2, 983), (2, 985), (1, 986), (4, 984), (3, 983), (3, 985), (2, 982), (2, 986), (1, 987), (5, 984), (4, 983), (4, 985), (3, 982), (3, 986), (2, 987), (1, 988), (6, 984), (5, 983), (5, 985), (4, 982), (4, 986), (3, 981), (3, 987), (2, 988), (1, 989), (7, 984), (6, 983), (6, 985), (5, 982), (5, 986), (4, 981), (4, 987), (3, 980), (3, 988), (2, 989), (8, 984), (7, 983), (7, 985), (6, 982), (6, 986), (5, 981), (5, 987), (4, 980), (4, 988), (3, 989), (2, 990), (9, 984), (8, 983), (8, 985), (7, 982), (7, 986), (6, 981), (6, 987), (5, 980), (5, 988), (4, 979), (4, 989), (3, 990), (2, 991), (10, 984), (9, 983), (9, 985), (8, 982), (8, 986), (7, 981), (7, 987), (6, 980), (6, 988), (5, 979), (5, 989), (4, 990), (3, 991), (11, 984), (10, 983), (10, 985), (9, 982), (9, 986), (8, 981), (8, 987), (7, 980), (7, 988), (6, 979), (6, 989), (5, 978), (5, 990), (4, 991), (3, 992), (12, 984), (11, 983), (11, 985), (10, 982), (10, 986), (9, 981), (9, 987), (8, 980), (8, 988), (7, 979), (7, 989), (6, 978), (6, 990), (5, 991), (4, 992), (13, 984), (12, 983), (12, 985), (11, 982), (11,
(1598, 498), (1598, 506), (1597, 497), (1597, 507), (1596, 496), (1596, 508), (1595, 509), (1594, 510), (1593, 511), (1599, 498), (1599, 506), (1598, 497), (1598, 507), (1597, 496), (1597, 508), (1596, 495), (1596, 509), (1595, 510), (1594, 511), (1593, 512), (1599, 497), (1599, 507), (1598, 496), (1598, 508), (1597, 495), (1597, 509), (1596, 510), (1595, 511), (1594, 512), (1599, 496), (1599, 508), (1598, 495), (1598, 509), (1597, 510), (1596, 511), (1595, 512), (1594, 513), (1599, 495), (1599, 509), (1598, 494), (1598, 510), (1597, 511), (1596, 512), (1595, 513), (1599, 494), (1599, 510), (1598, 511), (1597, 512), (1596, 513), (1595, 514), (1599, 511), (1598, 512), (1597, 513), (1596, 514), (1599, 512), (1598, 513), (1597, 514), (1599, 513)] mass:180>>
# Total Flubbers (>= P) count: 285

# %% [markdown]
# ### Unit Testing:

# %%
from FlubClub import *

# %%
dir(Flubber)

# %%
import glob, os
from PIL import ImageOps

links = []
for i in sorted(glob.glob('run6/*.jpg')):
    
    links.append('run6/frame' + i[10:15] + '.jpg')

frameZero = Image.open(str(links[0]), mode = 'r')
flubberFinder(25, frameZero, 650);
plt.figure(figsize = (15, 9))
plt.imshow(frameZero);

#FlubberMassGalore(25, 650, frameZero)

# %%
def displayRep(N, tau):
    plt.figure(figsize = (15, 9))
    plt.subplot(121)
    tempImage = Image.open(links[N])
    plt.title('Original Frame', fontsize = 22)
    plt.xlabel('Width [pixels]', fontsize = 18)
    plt.ylabel('Height [pixels]', fontsize = 18)
    plt.imshow(tempImage)
    plt.subplot(122)
    plt.title('Luminosity Threshold Applied', fontsize = 22)
    plt.xlabel('Width [pixels]', fontsize = 18)
    plt.ylabel('Height [pixels]', fontsize = 18)
    monochrome(tempImage, tau)
    plt.imshow(tempImage)
    plt.show()

wig = interact(displayRep, N = (0, 200), tau = (0, 700))

# %%
links = []
for i in sorted(glob.glob('milkLewis/Lewis_T*.jpg')):
    
    links.append('milkLewis/Lewis_T' + i[17:21] + '.jpg')

def displayRep(N, tau, P):
   
    plt.figure(figsize = (15, 9))
    plt.subplot(121)
    tempImage = Image.open(links[N])
    #plt.flubberFinder(P, tempImage, tau)
    plt.title('Original Frame', fontsize = 22)
    plt.xlabel('Width [pixels]', fontsize = 18)
    plt.ylabel('Height [pixels]', fontsize = 18)
    plt.imshow(tempImage)
    plt.subplot(122)
    plt.title('Luminosity Threshold Applied', fontsize = 22)
    plt.xlabel('Width [pixels]', fontsize = 18)
    plt.ylabel('Height [pixels]', fontsize = 18)
    img = ImageOps.invert(tempImage) #### Need to Invert the image. 
    monochrome(img, tau)
    plt.imshow(img)
    plt.show()

wig = interact(displayRep, N = (0, 200), tau = (0, 700), P = (5, 35))
#### tau = 570 seems to be optimal. 
#### tau for milk = 172

# %%
# Test string creation algorithms:
print links[4:10]

# %%
tempImage = Image.open(links[1])
monochrome(tempImage, 330)
plt.figure(figsize = (15, 9))
plt.imshow(tempImage)

# %%
flub = flubberFinder(25, tempImage, 500)
print flub[4].mass()

# %%
for f in flub:
    print f.mass()

# %% [markdown]
# #### Trash code:

# %%
    #  if os.path.isfile('picture'): 
    #    im = array(Image.open('picture'))
    #    if im == None or im.size == 0:
    #        print 'Image loaded is empty'
    #        sys.exit(1)
    
    
    
    

    
    
    
    
#def circularInterpolation(listFlubbers): # Attempting to apply Bezier's tripled linear interpolation for curves.
    # Want to extract endpoints. Optionally, use COM and sub/add max(radius) of flubber length.
    # Note: Another method of doing this would be to use masks and samplings to generate a circular flubber.
    
#    for i in listFlubbers:
#        x1 = i.centerOfMass - (i.mass / 2.); x2 = i.centerOfMass + (i.mass / 2.);
#        y1 = i.centerOfMass - (i.mass / 2.); y2 = i.centerOfMass + (i.mass / 2.);




#if __name__ == "__main__":
#    p = 25
#    tau = 600
#    print tau, p
    # pictureObject = # call from drive.
    # BlobFinder(pictureObject, tau)
    
    
    
    
                    
    #for (r,g,b) in picture.getdata():
    #    if r+g+b >= tau:
    #        tempImage[x, y] = BLACK
    #    else:
    #        tempImage[x, y] == WHITE
    
    if type(picture) == str:
        img = StringIO()
        img.write(open(str(picture), 'rb').read())
        #seek back to the beginning so the whole thing will be read by PIL
        img.seek(0)
        tempImage = Image.open(StringIO(img)); horLen, verLen = tempImage.size; 
    elif type(picture) == object:
        tempImage = picture.load(); horLen, verLen = picture.size; 
        
        
            #try:
    #    tempImage.load(); horLen, verLen = tempImage.size;
    #    plt.imshow(tempImage)
        
    #except AttributeError:
    #    print "Unable to load image. String vs Object problems."

    
        # Need to handle filter color information in images:
    #if hasattr(picture, '__iter__') == True:  # is an Array.
    #    for i in picture:
            #tempImage = Image.open(i)
    #        monochrome(picture, tau)
            # Compile a list of flubbers. This function will point image to fill process.
    #        fullFlubberInfo = count(P, tempImage, tau, Flubber, flubberMass, flubberCOM)
   # elif hasattr(picture, '__iter__') == False: # Is not an array.
        #tempImage = Image.open(StringIO(picture))
     #   monochrome(picture, tau)
        # Compile a list of flubbers. This function will point image to fill process.
    #    fullFlubberInfo = count(P, picture, tau, Flubber, flubberMass, flubberCOM) 
    
    
    

    
    
    #def count(P, picture, tau, Flubber, fM, fCOM):
#    '''Scan image from top left, to bottom right using nested loops. 
#    Black pixels are counted and fill function is called to create a circular representation of a flubber.
#    This is done by recognizing same-state pixels near it.
#    Once neighboring pixels are determined, they are assigned to the current flubber array.'''
#    BLACK = (0, 0, 0); RED = (255, 0, 0); tempImage = picture.load(); 
#    horLen, verLen = picture.size; flubberCount = 0; flubberMassInfo = [];
#    for x in range(horLen):
#        for y in range(verLen):
#            if tempImage[x,y] == BLACK:
#                
#                fill(tempImage, horLen, verLen, x, y, Flubber)
#                Flubber.mass()
#                Flubber.centerOfMass
#                #print str(Flubber.loc), str(Flubber.mass) #, Flubber.centerOfMass
#                flubberMassInfo.append(Flubber)
#    qualFlubbers = qualityFlubbers(P, flubberMassInfo)
#    flubberCount = numFlubber(P, qualFlubbers)
#
#    return flubberCount, qualFlubbers, flubberMassInfo
